# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
fig=plt.figure()
ax=plt.axes()

x = np.linspace(0, 10, 1000)
plt.plot(x,np.sin(x))

# %% [markdown]
# # Adjusting the Plot: Line Colors and Styles

# %%
y=[2,4,5]
plt.plot(y,[i**1 for i in y],color='black')
plt.plot(y,[i**1.5 for i in y],color='orange')
plt.plot(y,[i**2 for i in y],color='b')
plt.plot(y,[i**2.5 for i in y],color='green')
plt.plot(y,[i**3 for i in y],color='yellow')
plt.plot(y,[i**3.5 for i in y],color='black')
plt.plot(y,[i**4 for i in y],'violet')

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# # Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
plt.plot(x, np.sin(x), '-.r')
plt.axis([-1, 11, -1.5, 1.5])   ###   [xmin, xmax, ymin, ymax]
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %% [markdown]
# # Labeling Plots

# %%
plt.plot(x,np.sin(x))
plt.title('KyLan')
plt.xlabel('truc x')
plt.ylabel('truc Sin(x)')
# Out:
# Text(0, 0.5, 'truc Sin(x)')

# %%
plt.plot(x, np.sin(x), '-r', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, '+');

# %% [markdown]
# # Simple Scatter Plots

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-v',color='r',linewidth=5,markersize=20);

# %%
plt.scatter(x,y,marker='+',color=)

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  5.,  21.,  70., 185., 229., 259., 152.,  64.,  10.,   5.]),
#  array([-3.45524097, -2.75295914, -2.05067732, -1.3483955 , -0.64611368,
#          0.05616815,  0.75844997,  1.46073179,  2.16301361,  2.86529544,
#          3.56757726]),
#  <BarContainer object of 10 artists>)

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
ax.legend(loc='upper left', frameon=False)
fig

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])
plt.style.use('seaborn-white')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)
