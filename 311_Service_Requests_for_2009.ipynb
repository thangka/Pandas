# %% [markdown]
# # https://www.kaggle.com/learn/pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 60)
pd.set_option('max_row',5)

# %%
pwd
# Out:
# 'C:\\Users\\nguye\\Pandas'

# %%
import os
os.chdir('E:\PYTHON')

# %%
pwd
# Out:
# 'E:\\PYTHON'

# %%
dt=pd.read_csv(r'E:\PYTHON\311_Service_Requests_for_2009.csv',low_memory=False)

# %%
display(dt.head(1),dt.shape)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    12824180  01/01/2009 12:00:00 AM  01/08/2009 12:00:00 AM    DPR
#
#                           Agency Name           Complaint Type  \
# 0  Department of Parks and Recreation  Maintenance or Facility
#
#              Descriptor Location Type Incident Zip Incident Address  \
# 0  Structure - Outdoors          Park        10033              NaN
#
#   Street Name Cross Street 1 Cross Street 2 Intersection Street 1  \
# 0         NaN            NaN            NaN                   NaN
#
#   Intersection Street 2 Address Type      City Landmark Facility Type  Status  \
# 0                   NaN          NaN  NEW YORK      NaN           NaN  Closed
#
#                  Due Date Resolution Action Updated Date Community Board  \
# 0  01/15/2009 12:00:00 AM         01/08/2009 12:00:00 AM    12 MANHATTAN
#
#      Borough  X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# ...

# %%
dt.set_axis([i.lower() for i in dt.columns],1,inplace=True)
dt
# Out:
#          unique key            created date             closed date agency  \
# 0          12824180  01/01/2009 12:00:00 AM  01/08/2009 12:00:00 AM    DPR
# 1          12882475  01/08/2009 12:00:00 AM  01/08/2009 12:00:00 AM    DOT
# ...             ...                     ...                     ...    ...
# 1783131    14039954  05/26/2009 12:00:00 AM  05/28/2009 12:00:00 AM    HPD
# 1783132    14161381  06/11/2009 12:00:00 AM  06/11/2009 12:00:00 AM    DOB
#
#                                                agency name  \
# 0                       Department of Parks and Recreation
# 1                             Department of Transportation
# ...                                                    ...
# 1783131  Department of Housing Preservation and Develop...
# 1783132                            Department of Buildings
#
#                   complaint type                           descriptor  \
# 0        Maintenance or Facility                 Structure - Outdoors
# ...

# %%
import re
li=sorted([re.sub(' ','',i).lower() for i in dt.columns])
li
# Out:
# ['addresstype',
#  'agency',
#  'agencyname',
#  'borough',
#  'bridgehighwaydirection',
#  'bridgehighwayname',
#  'bridgehighwaysegment',
#  'city',
#  'closeddate',
#  'communityboard',
#  'complainttype',
#  'createddate',
#  'crossstreet1',
#  'crossstreet2',
#  'descriptor',
#  'duedate',
#  'facilitytype',
#  'ferrydirection',
#  'ferryterminalname',
#  'garagelotname',
#  'incidentaddress',
#  'incidentzip',
#  'intersectionstreet1',
#  'intersectionstreet2',
#  'landmark',
#  'latitude',
#  'location',
#  'locationtype',
#  'longitude',
#  'parkborough',
#  'parkfacilityname',
#  'resolutionactionupdateddate',
#  'roadramp',
#  'schooladdress',
#  'schoolcity',
#  'schoolcode',
#  'schoolname',
#  'schoolnotfound',
#  'schoolnumber',
#  'schoolorcitywidecomplaint',
#  'schoolphonenumber',
#  'schoolregion',
#  'schoolstate',
#  'schoolzip',
#  'status',
#  'streetname',
#  'taxicompanyborough',
#  'taxipickuplocation',
#  'uniquekey',
#  'vehicletype',
# ...

# %%
dt.loc[dt['location type']=='Park',['unique key','location type']]
# Out:
#          unique key location type
# 0          12824180          Park
# 12         12824945          Park
# ...             ...           ...
# 1782608    13312667          Park
# 1782809    14679147          Park
#
# [10120 rows x 2 columns]

# %%
dt['incident zip'].str.contains('[^0-9]')
# Out:
# 0          False
# 1            NaN
#            ...
# 1783131    False
# 1783132    False
# Name: incident zip, Length: 1783133, dtype: object

# %%
dt[~(dt['incident zip'].fillna('-')).str.contains('\D')]['incident zip'].unique()
# Out:
# array(['10033', '11216', '10010', '11209', '07030', '10027', '10002',
#        '07927', '10023', '11375', '11220', '10458', '10456', '10471',
#        '11224', '11235', '10462', '23502', '12345', '44113', '11236',
#        '07632', '10550', '11214', '30328', '10472', '10025', '11581',
#        '11377', '11735', '20850', '10028', '11766', '10021', '11797',
#        '07020', '11366', '11361', '11426', '11549', '10459', '55344',
#        '11215', '11434', '10039', '07302', '10467', '18773', '10004',
#        '92683', '10024', '33319', '11201', '10035', '11218', '11749',
#        '11356', '10012', '11205', '00000', '15561', '10304', '10457',
#        '10003', '10468', '10305', '10309', '19850', '84117', '56303',
#        '11211', '11692', '10026', '08003', '07114', '11530', '11590',
#        '11561', '11772', '11368', '10029', '07962', '85004', '75234',
#        '14009', '11219', '11354', '11360', '0000', '19044', '11355',
# ...

# %%
dt.de
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-fbdcf633f550> in <module>
# ----> 1 dt['incident zip'].map(lambda x: int(x)*2)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-108-fbdcf633f550> in <lambda>(x)
# ...
